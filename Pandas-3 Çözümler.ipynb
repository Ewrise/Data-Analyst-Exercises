# %%
import pandas as pd
import numpy as np

# %%
# mpg.csv dosyasını okuyun ve df değişkenine atayın.

df = pd.read_csv("mpg.csv")
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# 1) df'in içindeki sütunların birbirleriyle olan korelasyonlarına(ilişkilerine) bakın.

df.corr()
# Out:
# C:\Users\Fallrytme\AppData\Local\Temp\ipykernel_4776\2775034619.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
# 2) mpg sütunu ile diğer sütunların arasındaki korelasyonları özel olarak inceleyin.(Bunu göstermedik ama df.corr() çağırdıktan sonra aynı normal df'lerde olduğu gibi istediğiniz sütunu çağırabiliyorsunuz.)

df.corr()["mpg"]
# Out:
# C:\Users\Fallrytme\AppData\Local\Temp\ipykernel_4776\1328845232.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["mpg"]
# mpg             1.000000
# cylinders      -0.775396
# displacement   -0.804203
# weight         -0.831741
# acceleration    0.420289
# model_year      0.579267
# origin          0.563450
# Name: mpg, dtype: float64

# %%
# 3) cylinders sütununda hangi unique değerler olduğuna liste halinde bakın.

list(df["cylinders"].unique())
# Out:
# [8, 4, 6, 3, 5]

# %%
# 4) cylinders sütunundaki unique değerlerin her birinden kaçar adet olduğuna bakın.

df["cylinders"].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
# 5) Arabanın modeli 75-80 yılları arasındaki arabaların hepsini getirin.(75 ve 80 dahil)

df[df["model_year"].between(75, 80, inclusive= "both")]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 152  19.0          6         225.0         95    3264          16.0
# 153  18.0          6         250.0        105    3459          16.0
# 154  15.0          6         250.0         72    3432          21.0
# 155  15.0          6         250.0         72    3158          19.5
# 156  16.0          8         400.0        170    4668          11.5
# ..    ...        ...           ...        ...     ...           ...
# 333  32.7          6         168.0        132    2910          11.4
# 334  23.7          3          70.0        100    2420          12.5
# 335  35.0          4         122.0         88    2500          15.1
# 336  23.6          4         140.0          ?    2905          14.3
# 337  32.4          4         107.0         72    2290          17.0
#
#      model_year  origin                     name
# 152          75       1  plymouth valiant custom
# 153          75       1           chevrolet nova
# 154          75       1          mercury monarch
# 155          75       1            ford maverick
# 156          75       1         pontiac catalina
# ..          ...     ...                      ...
# 333          80       3            datsun 280-zx
# 334          80       3            mazda rx-7 gs
# 335          80       2        triumph tr7 coupe
# 336          80       1       ford mustang cobra
# 337          80       3             honda accord
#
# [186 rows x 9 columns]

# %%
# 6) horsepower'ı 155-180 arasındaki arabaların hepsini getirin.(155 dahil, 180 dahil değil)(Bu sorguyu yapabilmeniz için horsepower sütununu object durumdan float duruma getirmeniz gerekiyor.)

df[df["horsepower"].replace("?", np.nan).astype(float).between(155, 180, inclusive= "left")]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 1    15.0          8         350.0        165    3693          11.5
# 10   15.0          8         383.0        170    3563          10.0
# 11   14.0          8         340.0        160    3609           8.0
# 38   14.0          8         350.0        165    4209          12.0
# 39   14.0          8         400.0        175    4464          11.5
# 43   13.0          8         400.0        170    4746          12.0
# 44   13.0          8         400.0        175    5140          12.0
# 62   13.0          8         350.0        165    4274          12.0
# 63   14.0          8         400.0        175    4385          12.0
# 68   13.0          8         350.0        155    4502          13.5
# 69   12.0          8         350.0        160    4456          13.5
# 85   13.0          8         350.0        175    4100          13.0
# 92   13.0          8         351.0        158    4363          13.0
# 96   13.0          8         360.0        175    3821          11.0
# 104  12.0          8         400.0        167    4906          12.5
# 105  13.0          8         360.0        170    4654          13.0
# 156  16.0          8         400.0        170    4668          11.5
# 230  15.5          8         350.0        170    4165          11.4
# 263  17.7          6         231.0        165    3445          13.4
# 289  16.9          8         350.0        155    4360          14.9
#
#      model_year  origin                             name
# 1            70       1                buick skylark 320
# 10           70       1              dodge challenger se
# 11           70       1               plymouth 'cuda 340
# 38           71       1                 chevrolet impala
# 39           71       1        pontiac catalina brougham
# 43           71       1         ford country squire (sw)
# 44           71       1              pontiac safari (sw)
# 62           72       1                 chevrolet impala
# 63           72       1                 pontiac catalina
# 68           72       1             buick lesabre custom
# 69           72       1       oldsmobile delta 88 royale
# 85           73       1                buick century 350
# 92           73       1                         ford ltd
# 96           73       1          amc ambassador brougham
# 104          73       1                     ford country
# 105          73       1           plymouth custom suburb
# 156          75       1                 pontiac catalina
# 230          77       1     chevrolet monte carlo landau
# 263          78       1  buick regal sport coupe (turbo)
# 289          79       1          buick estate wagon (sw)

# %%
# 7) Elinizdeki df'i horsepower'a göre büyükten küçüğe sıralayın ardından df'in indexlerini sıfırlayın.
df["horsepower"] = df["horsepower"].replace("?", np.nan).astype(float)
df.sort_values("horsepower", ascending= False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 116  16.0          8         400.0       230.0    4278           9.5
# 95   12.0          8         455.0       225.0    4951          11.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# ..    ...        ...           ...         ...     ...           ...
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                      name
# 116          73       1        pontiac grand prix
# 95           73       1  buick electra 225 custom
# 13           70       1   buick estate wagon (sw)
# 8            70       1          pontiac catalina
# 6            70       1          chevrolet impala
# ..          ...     ...                       ...
# 126          74       1             ford maverick
# 330          80       2      renault lecar deluxe
# 336          80       1        ford mustang cobra
# 354          81       2               renault 18i
# 374          82       1            amc concord dl
#
# [398 rows x 9 columns]

# %%
# 8) Elinizdeki df'den en küçük 5 acceralation'a sahip olan arabaları getirin.

df.sort_values("acceleration").head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0       160.0    3609           8.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 7    14.0          8         440.0       215.0    4312           8.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 116  16.0          8         400.0       230.0    4278           9.5
#
#      model_year  origin                name
# 11           70       1  plymouth 'cuda 340
# 9            70       1  amc ambassador dpl
# 7            70       1   plymouth fury iii
# 6            70       1    chevrolet impala
# 116          73       1  pontiac grand prix

# %%
# --- CIA_Country_Facts.csv dosyasını okuyun ve yeniden df değişkenine atayın.(Artık eski df ile işimiz kalmadığı için aynı ismi verebiliriz.)

df = pd.read_csv("CIA_Country_Facts.csv")
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      15.11       5.22        0.232     0.188    0.579
# 2      17.14       4.61        0.101     0.600    0.298
# 3      22.46       3.27          NaN       NaN      NaN
# 4       8.71       6.25          NaN       NaN      NaN

# %%
# 9) Elimizdeki CIA'in ülkeler hakkında topladığı basit açık kaynak verileri df'inde kaç ülkenin verisi olduğunu bulun.

len(df["Country"].unique())
# Out:
# 227

# %%
# 10) Elimizdeki sütunlardan hangilerinde kaçar tane nan veri olduğunu bulun.

df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
# 11) Elimizde tamamen nan değerlerden oluşan bir satır varsa o satırı düşürün.(Tamamen nan değerlerden oluşan bir satır olup olmadığını, herhangi bir satırın düşüp düşmediğini kontrol edin)

df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0            647500                        48.0                          0.00
# 1             28748                       124.6                          1.26
# 2           2381740                        13.8                          0.04
# 3               199                       290.4                         58.29
# 4               468                       152.1                          0.00
# ..              ...                         ...                           ...
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0            23.06                              163.07               700.0
# 1            -4.93                               21.52              4500.0
# 2            -0.39                               31.00              6000.0
# 3           -20.71                                9.27              8000.0
# 4             6.60                                4.05             19000.0
# ..             ...                                 ...                 ...
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0            36.0                3.2       12.13       0.22      87.65
# 1            86.5               71.2       21.09       4.42      74.49
# 2            70.0               78.1        3.22       0.25      96.53
# 3            97.0              259.5       10.00      15.00      75.00
# 4           100.0              497.2        2.22       0.00      97.78
# ..            ...                ...         ...        ...        ...
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# 1        3.0      15.11       5.22        0.232     0.188    0.579
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 3        2.0      22.46       3.27          NaN       NaN      NaN
# 4        3.0       8.71       6.25          NaN       NaN      NaN
# ..       ...        ...        ...          ...       ...      ...
# 222      3.0      31.67       3.92        0.090     0.280    0.630
# 223      1.0        NaN        NaN          NaN       NaN    0.400
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 225      2.0      41.00      19.93        0.220     0.290    0.489
# 226      2.0      28.01      21.84        0.179     0.243    0.579
#
# [227 rows x 20 columns]

# %%
df.dropna(how= "all")

# Bütün sütunları Nan olan bir satır yokmuş.
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0            647500                        48.0                          0.00
# 1             28748                       124.6                          1.26
# 2           2381740                        13.8                          0.04
# 3               199                       290.4                         58.29
# 4               468                       152.1                          0.00
# ..              ...                         ...                           ...
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0            23.06                              163.07               700.0
# 1            -4.93                               21.52              4500.0
# 2            -0.39                               31.00              6000.0
# 3           -20.71                                9.27              8000.0
# 4             6.60                                4.05             19000.0
# ..             ...                                 ...                 ...
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0            36.0                3.2       12.13       0.22      87.65
# 1            86.5               71.2       21.09       4.42      74.49
# 2            70.0               78.1        3.22       0.25      96.53
# 3            97.0              259.5       10.00      15.00      75.00
# 4           100.0              497.2        2.22       0.00      97.78
# ..            ...                ...         ...        ...        ...
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# 1        3.0      15.11       5.22        0.232     0.188    0.579
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 3        2.0      22.46       3.27          NaN       NaN      NaN
# 4        3.0       8.71       6.25          NaN       NaN      NaN
# ..       ...        ...        ...          ...       ...      ...
# 222      3.0      31.67       3.92        0.090     0.280    0.630
# 223      1.0        NaN        NaN          NaN       NaN    0.400
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 225      2.0      41.00      19.93        0.220     0.290    0.489
# 226      2.0      28.01      21.84        0.179     0.243    0.579
#
# [227 rows x 20 columns]

# %%
# 12) Her Bölgedeki(Region) toplam kişi sayısına bakın.

df.groupby("Region").sum()["Population"]
# Out:
# C:\Users\Fallrytme\AppData\Local\Temp\ipykernel_4776\2494190559.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Region").sum()["Population"]
# Region
# ASIA (EX. NEAR EAST)                   3687982236
# BALTICS                                   7184974
# C.W. OF IND. STATES                     280081548
# EASTERN EUROPE                          119914717
# LATIN AMER. & CARIB                     561824599
# NEAR EAST                               195068377
# NORTHERN AFRICA                         161407133
# NORTHERN AMERICA                        331672307
# OCEANIA                                  33131662
# SUB-SAHARAN AFRICA                      749437000
# WESTERN EUROPE                          396339998
# Name: Population, dtype: int64

# %%
# 13) Climate değerleri nan olanlar, tüm df'in ortalama climate değeriyle doldurun.(Gerçek bir analiz yapıyor olsaydık bu çok mantıklı bir hareket olmazdı, belki her bulunduğu bölgenin ortalama climate değeriyle doldurmak daha mantıklı bir hareket olurdu. Fakat şimdilik bu kadar kasmaya gerek yok. nan değerleri tüm climate ortalamalarıyla doldursanız yeterli.)

df["Climate"].fillna(df["Climate"].mean())
# Out:
# 0      1.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      3.0
#       ...
# 222    3.0
# 223    1.0
# 224    1.0
# 225    2.0
# 226    2.0
# Name: Climate, Length: 227, dtype: float64

# %%
# 14) Bölgeler ve Ülkelere göre gruplama yapın ardından Doğum miktarlarına bakın.

df.groupby(["Region", "Country"])["Birthrate"].mean()
# Out:
# Region                               Country
# ASIA (EX. NEAR EAST)                 Afghanistan       46.60
#                                      Bangladesh        29.80
#                                      Bhutan            33.65
#                                      Brunei            18.79
#                                      Burma             17.91
#                                                        ...
# WESTERN EUROPE                       San Marino        10.02
#                                      Spain             10.06
#                                      Sweden            10.27
#                                      Switzerland        9.71
#                                      United Kingdom    10.71
# Name: Birthrate, Length: 227, dtype: float64

# %%
# 15) Veriyi istediğiniz şekilde inceleyerek bu zamana kadar öğrendiğiniz bilgilerle anlamlı 5 adet yargı cümlesi çıkartın. ( En çok insan Asya kıtasında yaşıyor, En çok insan Afrinın sahralarında ölüyor, Ortalama en yüksek telefon sahibi Kuzey Amerikada, En çok okuma yazma oranına sahip ülkeler Baltık ülkeleri vb.)

df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      15.11       5.22        0.232     0.188    0.579
# 2      17.14       4.61        0.101     0.600    0.298
# 3      22.46       3.27          NaN       NaN      NaN
# 4       8.71       6.25          NaN       NaN      NaN

# %%
df.sort_values("Population", ascending= False)

# En çok insan popülasyonu Çinde.
# Out:
#                   Country                               Region  Population  \
# 42                  China        ASIA (EX. NEAR EAST)           1313973713
# 94                  India        ASIA (EX. NEAR EAST)           1095351995
# 214         United States  NORTHERN AMERICA                      298444215
# 95              Indonesia        ASIA (EX. NEAR EAST)            245452739
# 27                 Brazil              LATIN AMER. & CARIB       188078227
# ..                    ...                                  ...         ...
# 144                 Nauru  OCEANIA                                   13287
# 209                Tuvalu  OCEANIA                                   11810
# 140            Montserrat              LATIN AMER. & CARIB            9439
# 171          Saint Helena  SUB-SAHARAN AFRICA                         7502
# 174  St Pierre & Miquelon  NORTHERN AMERICA                           7026
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 42          9596960                       136.9                          0.15
# 94          3287590                       333.2                          0.21
# 214         9631420                        31.0                          0.21
# 95          1919440                       127.9                          2.85
# 27          8511965                        22.1                          0.09
# ..              ...                         ...                           ...
# 144              21                       632.7                        142.86
# 209              26                       454.2                         92.31
# 140             102                        92.5                         39.22
# 171             413                        18.2                         14.53
# 174             242                        29.0                         49.59
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 42           -0.40                               24.18              5000.0
# 94           -0.07                               56.29              2900.0
# 214           3.41                                6.50             37800.0
# 95            0.00                               35.60              3200.0
# 27           -0.03                               29.61              7600.0
# ..             ...                                 ...                 ...
# 144           0.00                                9.95              5000.0
# 209           0.00                               20.03              1100.0
# 140           0.00                                7.35              3400.0
# 171           0.00                               19.00              2500.0
# 174          -4.86                                7.54              6900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 42           90.9              266.7       15.40       1.25      83.35
# 94           59.5               45.4       54.40       2.74      42.86
# 214          97.0              898.0       19.13       0.22      80.65
# 95           87.9               52.0       11.32       7.23      81.45
# 27           86.4              225.3        6.96       0.90      92.15
# ..            ...                ...         ...        ...        ...
# 144           NaN              143.0        0.00       0.00     100.00
# 209           NaN               59.3        0.00       0.00     100.00
# 140          97.0                NaN       20.00       0.00      80.00
# 171          97.0              293.3       12.90       0.00      87.10
# 174          99.0              683.2       13.04       0.00      86.96
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 42       1.5      13.25       6.97        0.125     0.473    0.403
# 94       2.5      22.01       8.18        0.186     0.276    0.538
# 214      3.0      14.14       8.26        0.010     0.204    0.787
# 95       2.0      20.34       6.25        0.134     0.458    0.408
# 27       2.0      16.56       6.17        0.084     0.400    0.516
# ..       ...        ...        ...          ...       ...      ...
# 144      2.0      24.76       6.70          NaN       NaN      NaN
# 209      2.0      22.18       7.11        0.166     0.272    0.562
# 140      2.0      17.59       7.10          NaN       NaN      NaN
# 171      NaN      12.13       6.53          NaN       NaN      NaN
# 174      NaN      13.52       6.83          NaN       NaN      NaN
#
# [227 rows x 20 columns]

# %%
df.sort_values("Literacy (%)")

# En düşük okuryazarlık Niger ülkesinde.
# Out:
#              Country                               Region  Population  \
# 151            Niger  SUB-SAHARAN AFRICA                     12525094
# 31      Burkina Faso  SUB-SAHARAN AFRICA                     13902972
# 183     Sierra Leone  SUB-SAHARAN AFRICA                      6005250
# 86            Guinea  SUB-SAHARAN AFRICA                      9690222
# 0        Afghanistan        ASIA (EX. NEAR EAST)             31056997
# ..               ...                                  ...         ...
# 187  Solomon Islands  OCEANIA                                  552438
# 209           Tuvalu  OCEANIA                                   11810
# 220   Virgin Islands              LATIN AMER. & CARIB          108605
# 222        West Bank  NEAR EAST                               2460492
# 223   Western Sahara  NORTHERN AFRICA                          273008
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 151         1267000                         9.9                          0.00
# 31           274200                        50.7                          0.00
# 183           71740                        83.7                          0.56
# 86           245857                        39.4                          0.13
# 0            647500                        48.0                          0.00
# ..              ...                         ...                           ...
# 187           28450                        19.4                         18.67
# 209              26                       454.2                         92.31
# 220            1910                        56.9                          9.84
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 151          -0.67                              121.69               800.0
# 31            0.00                               97.57              1100.0
# 183           0.00                              143.64               500.0
# 86           -3.06                               90.37              2100.0
# 0            23.06                              163.07               700.0
# ..             ...                                 ...                 ...
# 187           0.00                               21.29              1700.0
# 209           0.00                               20.03              1100.0
# 220          -8.94                                8.03             17200.0
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 151          17.6                1.9        3.54       0.01      96.45
# 31           26.6                7.0       14.43       0.19      85.38
# 183          31.4                4.0        6.98       0.89      92.13
# 86           35.9                2.7        3.63       2.58      93.79
# 0            36.0                3.2       12.13       0.22      87.65
# ..            ...                ...         ...        ...        ...
# 187           NaN               13.4        0.64       2.00      97.36
# 209           NaN               59.3        0.00       0.00     100.00
# 220           NaN              652.8       11.76       2.94      85.30
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 151      1.0      50.73      20.91        0.390     0.170    0.440
# 31       2.0      45.62      15.60        0.322     0.196    0.482
# 183      2.0      45.76      23.03        0.490     0.310    0.210
# 86       2.0      41.76      15.48        0.237     0.362    0.401
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# ..       ...        ...        ...          ...       ...      ...
# 187      2.0      30.01       3.92        0.420     0.110    0.470
# 209      2.0      22.18       7.11        0.166     0.272    0.562
# 220      2.0      13.96       6.43        0.010     0.190    0.800
# 222      3.0      31.67       3.92        0.090     0.280    0.630
# 223      1.0        NaN        NaN          NaN       NaN    0.400
#
# [227 rows x 20 columns]

# %%
df["Region"].value_counts()

# En çok ülke Sahra altı Afrika'da bulunuyor.
# Out:
# SUB-SAHARAN AFRICA                     51
# LATIN AMER. & CARIB                    45
# ASIA (EX. NEAR EAST)                   28
# WESTERN EUROPE                         28
# OCEANIA                                21
# NEAR EAST                              16
# EASTERN EUROPE                         12
# C.W. OF IND. STATES                    12
# NORTHERN AFRICA                         6
# NORTHERN AMERICA                        5
# BALTICS                                 3
# Name: Region, dtype: int64

# %%
df.groupby(["Region"])["Deathrate"].mean().sort_values()

# En az ölüm oranı Kuzey Afrikada bulunuyor.
# Out:
# Region
# NORTHERN AFRICA                         4.806000
# NEAR EAST                               4.809375
# OCEANIA                                 5.810526
# LATIN AMER. & CARIB                     6.376000
# ASIA (EX. NEAR EAST)                    7.637143
# NORTHERN AMERICA                        7.694000
# WESTERN EUROPE                          9.354643
# EASTERN EUROPE                         10.284545
# C.W. OF IND. STATES                    10.341667
# BALTICS                                12.630000
# SUB-SAHARAN AFRICA                     15.160000
# Name: Deathrate, dtype: float64

# %%
df.groupby(["Region"])[["Industry", "Agriculture"]].mean().sort_values("Industry", ascending= False)
# Out:
#                                      Industry  Agriculture
# Region
# NORTHERN AFRICA                      0.426200     0.135000
# NEAR EAST                            0.406000     0.063812
# C.W. OF IND. STATES                  0.328000     0.192000
# EASTERN EUROPE                       0.309250     0.092167
# ASIA (EX. NEAR EAST)                 0.302143     0.177643
# BALTICS                              0.293333     0.045000
# SUB-SAHARAN AFRICA                   0.266878     0.283551
# LATIN AMER. & CARIB                  0.256116     0.091023
# WESTERN EUROPE                       0.246083     0.044480
# OCEANIA                              0.215250     0.175125
# NORTHERN AMERICA                     0.199333     0.014000

# %%
df.groupby(["Region"])[["Industry", "Agriculture"]].mean().sort_values("Agriculture", ascending= False)

# En yüksek sanayileşme Kuzey Afrika bölgesinde bulunurken, en yüksek tarım Sahra Altı Afrikasında gerçekleştiriliyor.
# Out:
#                                      Industry  Agriculture
# Region
# SUB-SAHARAN AFRICA                   0.266878     0.283551
# C.W. OF IND. STATES                  0.328000     0.192000
# ASIA (EX. NEAR EAST)                 0.302143     0.177643
# OCEANIA                              0.215250     0.175125
# NORTHERN AFRICA                      0.426200     0.135000
# EASTERN EUROPE                       0.309250     0.092167
# LATIN AMER. & CARIB                  0.256116     0.091023
# NEAR EAST                            0.406000     0.063812
# BALTICS                              0.293333     0.045000
# WESTERN EUROPE                       0.246083     0.044480
# NORTHERN AMERICA                     0.199333     0.014000
