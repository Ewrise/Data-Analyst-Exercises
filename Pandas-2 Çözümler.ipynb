# %%
import pandas as pd
import numpy as np

# %%
# 1) df_tips içindeki Payment ID column'unun son 3 rakamını çekin. Bu işlemi 3 farklı yolla da yapmaya çalışın.

df_tips = pd.read_csv("tips.csv")
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
def son3(x):
  return str(x)[-3:]

df_tips["Payment ID"] = df_tips["Payment ID"].apply(son3)

df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410        959
# 1      Douglas Tucker  4478071379779230        608
# 2      Travis Walters  6011812112971322        458
# 3    Nathaniel Harris  4676137647685994        260
# 4        Tonya Carter  4832732618637221        251

# %%
df_tips = pd.read_csv("tips.csv")
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_tips["Payment ID"] = df_tips["Payment ID"].apply(lambda x : str(x)[-3:])
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name Payment ID
# 0  Christy Cunningham        959
# 1      Douglas Tucker        608
# 2      Travis Walters        458
# 3    Nathaniel Harris        260
# 4        Tonya Carter        251

# %%
df_tips = pd.read_csv("tips.csv")
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df_tips["Payment ID"] = df_tips["Payment ID"].astype(str).str[-3:]
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name Payment ID
# 0  Christy Cunningham        959
# 1      Douglas Tucker        608
# 2      Travis Walters        458
# 3    Nathaniel Harris        260
# 4        Tonya Carter        251

# %%
# 2) df_tips içindeki Payer Name sütununda isim ve soy isim bilgileri bulunuyor. O sütundan sadece isim bilgileri çekin ve 'JustName' adında yeni bir column oluşturun. (Bu biraz zorlayıcı olabilir, Önce kendiniz yapmaya çalışın fakat yapamazsanız ChatGPT'ye soruyu düzgünce sorarak cevabını kod olarak alabilirsiniz, ardından döndürülen kodu anlamaya çalışmanız yeterlidir.)

df_tips["Just Name"] = df_tips["Payer Name"].astype(str).str.split(" ").str[0]

df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  Just Name
# 0    Christy Cunningham  3560325168603410       2959    Christy
# 1        Douglas Tucker  4478071379779230       4608    Douglas
# 2        Travis Walters  6011812112971322       4458     Travis
# 3      Nathaniel Harris  4676137647685994       5260  Nathaniel
# 4          Tonya Carter  4832732618637221       2251      Tonya
# ..                  ...               ...        ...        ...
# 239       Michael Avila  5296068606052842       2657    Michael
# 240      Monica Sanders  3506806155565404       1766     Monica
# 241          Keith Wong  6011891618747196       3880      Keith
# 242        Dennis Dixon     4375220550950       at17     Dennis
# 243     Michelle Hardin  3511451626698139       r672   Michelle
#
# [244 rows x 12 columns]

# %%
# 3) 2.Soruda yeni oluşturduğunuz 'JustName' sütunundaki verilerin her birinden kaç tane olduğuna uygun methodu kullanarak bakın.

df_tips["Just Name"].value_counts()
# Out:
# Jason          9
# Michael        7
# James          6
# David          6
# Christopher    5
#               ..
# Shawna         1
# Louis          1
# Chris          1
# Mark           1
# Michelle       1
# Name: Just Name, Length: 153, dtype: int64

# %%
# 4) 3.Soruda gördüğünüz gibi JustName sütununda 'Jason' isminden 9 tane, 'Michael' isminden 7 tane , 'James' isminden 6 tane bulunuyor. Peki bunların hepsi gerçekten farklı kişiler mi ? Hemen 'Payer Name' sütunundaki verilerin adetlerini de saydırtarak bir kıyaslama yapın. 'JustName' sütununu kullanmanın faydasız ve yanıltıcı olabileceğini görün ardından oluşturduğumuz 'JustName' sütununu kalıcı olarak drop edin. (Oluşturmanız için bir pratikti bu sütun sadece :D)

df_tips["Payer Name"].value_counts()
# Out:
# Christy Cunningham    1
# Todd Patterson        1
# Madison Wilson        1
# Ryan Gonzales         1
# Laura Robles          1
#                      ..
# Shawna Cook           1
# Derek Thomas          1
# Donald Williams       1
# Roger Taylor          1
# Michelle Hardin       1
# Name: Payer Name, Length: 244, dtype: int64

# %%
df_tips.drop("Just Name", inplace= True, axis= 1)
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410       2959
# 1        Douglas Tucker  4478071379779230       4608
# 2        Travis Walters  6011812112971322       4458
# 3      Nathaniel Harris  4676137647685994       5260
# 4          Tonya Carter  4832732618637221       2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842       2657
# 240      Monica Sanders  3506806155565404       1766
# 241          Keith Wong  6011891618747196       3880
# 242        Dennis Dixon     4375220550950       at17
# 243     Michelle Hardin  3511451626698139       r672
#
# [244 rows x 11 columns]

# %%
# 5) Erkeklerin ve kadınların davranış patternlerini ayrı ayrı inceleyip yorumda bulunabilmek için 'df_male' ve 'df_female' adında 2 dataframe oluşturun. Birinde sadece 157 erkek verisi, diğerinde sadece 87 kadın verisi bulunsun.

df_male = df_tips[df_tips["sex"] == "Male"]
df_male
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# 1        Douglas Tucker  4478071379779230       4608
# 2        Travis Walters  6011812112971322       4458
# 3      Nathaniel Harris  4676137647685994       5260
# 5            Erik Smith   213140353657882       9679
# 6    Kristopher Johnson  2223727524230344       5985
# ..                  ...               ...        ...
# 236       Matthew Myers  3543676378973965       5032
# 237        Thomas Brown  4284722681265508       2929
# 239       Michael Avila  5296068606052842       2657
# 241          Keith Wong  6011891618747196       3880
# 242        Dennis Dixon     4375220550950       at17
#
# [157 rows x 11 columns]

# %%
df_female = df_tips[df_tips["sex"] == "Female"]
df_female
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410       2959
# 4          Tonya Carter  4832732618637221       2251
# 11         Diane Macias  4577817359320969       6686
# 14        Vanessa Jones    30016702287574       3848
# 16     Elizabeth Foster  4240025044626033       9715
# ..                  ...               ...        ...
# 226          Ruth Weiss  5268689490381635       6359
# 229    Jennifer Russell     4793003293608       3943
# 238      Kimberly Crane      676184013727       9777
# 240      Monica Sanders  3506806155565404       1766
# 243     Michelle Hardin  3511451626698139       r672
#
# [87 rows x 11 columns]

# %%
# 6) Ardından bu 'df_male' ile 'df_female' 'in ödedikleri bahşişler toplamını bulup karşılaştırın.

df_male["tip"].sum()
# Out:
# 485.07

# %%
df_female["tip"].sum()
# Out:
# 246.50999999999996

# %%
# 7) 6.Soruda erkeklerin ve kadınların ödedikleri bahşişler toplamına bakıldığında Erkeklerin kadınlara kıyasla toplamda daha çok bahşiş ödediğini görüyoruz. Fakat biz biliyoruz ki bizim verimizde 157 Erkek, 87 kadın verisi vardı. Dolayısıyla Erkek sayısı daha fazla olduğu için toplam ödeyecekleri bahşiş miktarlarında da daha fazla çıkması oldukça normal bir durum. Bu yüzden daha mantıklı bir çıkarım için bu sefer df_male ile df_female'in bahşiş ORTALAMALARIN'a bakıp kıyaslayın, aralarında anlamlı ve ciddi bir fark var mı ?

df_male["tip"].mean()
# Out:
# 3.0896178343949043

# %%
df_female["tip"].mean()
# Out:
# 2.8334482758620685

# %%
# 8) Oluşturmuş olduğunuz df_male ile çalışarak elimizdeki verideki erkeklerin yüzde kaçının sigara içtiğini bulun. Aynı şekilde elimizdeki kadınların yüzde kaçının sigara içtiğini de bulun. Aralarında anlamlı bir fark mı yorumlayın.

df_male["smoker"].value_counts(normalize= True) * 100
# Out:
# No     61.783439
# Yes    38.216561
# Name: smoker, dtype: float64

# %%
df_female["smoker"].value_counts(normalize= True) * 100
# Out:
# No     62.068966
# Yes    37.931034
# Name: smoker, dtype: float64

# %%
# 9) Erkeklerin zaman olarak dinnerda mı yoksa lunch'da mı daha fazla yemek yediğini yüzdesel olarak bulun. Aynı işlemi kadınlar için de yapın. Yüzdesel olarak erkeklerin ve kadınların yemek yeme vakitleri arasında anlamlı bir fark var mı yok mu yorumlayın.

df_male["time"].value_counts(normalize= True) * 100
# Out:
# Dinner    78.980892
# Lunch     21.019108
# Name: time, dtype: float64

# %%
df_female["time"].value_counts(normalize= True) * 100
# Out:
# Dinner    59.770115
# Lunch     40.229885
# Name: time, dtype: float64

# %%
# 10) CC Number sütununu kalıcı olarak drop edin. Ardından df'in içindeki sütunların birbirleriyle olan ilişkilerini inceleyin ve çıkan sonuçlar hakkında yorumlarınızı belirtin.

df_tips.drop("CC Number", inplace= True, axis= 1)
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name Payment ID
# 0    Christy Cunningham       2959
# 1        Douglas Tucker       4608
# 2        Travis Walters       4458
# 3      Nathaniel Harris       5260
# 4          Tonya Carter       2251
# ..                  ...        ...
# 239       Michael Avila       2657
# 240      Monica Sanders       1766
# 241          Keith Wong       3880
# 242        Dennis Dixon       at17
# 243     Michelle Hardin       r672
#
# [244 rows x 10 columns]

# %%
df_tips.groupby("size").mean()
# Out:
# C:\Users\Fallrytme\AppData\Local\Temp\ipykernel_15244\2299332357.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_tips.groupby("size").mean()
#       total_bill       tip  price_per_person
# size
# 1       7.242500  1.437500          7.242500
# 2      16.448013  2.582308          8.223910
# 3      23.277632  3.393158          7.759211
# 4      28.613514  4.135405          7.153243
# 5      30.068000  4.028000          6.014000
# 6      34.830000  5.225000          5.807500

# %%
df_tips.groupby(["day", "sex"]).sum()
# Out:
# C:\Users\Fallrytme\AppData\Local\Temp\ipykernel_15244\32944446.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_tips.groupby(["day", "sex"]).sum()
#              total_bill     tip  size  price_per_person
# day  sex
# Fri  Female      127.31   25.03    19             61.01
#      Male        198.57   26.93    21             93.52
# Sat  Female      551.05   78.45    63            244.25
#      Male       1227.35  181.95   156            468.00
# Sun  Female      357.70   60.61    53            121.94
#      Male       1269.46  186.78   163            475.70
# Thur Female      534.89   82.42    79            222.20
#      Male        561.44   89.41    73            238.10
